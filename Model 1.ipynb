# %%
import numpy as np

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Activation

from hyperas import optim
from hyperas.distributions import choice, uniform, conditional
from hyperopt import Trials, STATUS_OK, tpe

# %%
def create_model(x_train, y_train, x_test, y_test):
    # Expected input batch shape: (batch_size, timesteps, data_dim)
    # Note that we have to provide the full batch_input_shape since the network is stateful.
    # the sample of index i in batch k is the follow-up for the sample i in batch k-1.
    model = Sequential()
    #if conditional({{choice(['two', 'three'])}}) == 'two':
    model.add(LSTM(32, input_shape=(1, 1)))
    #else:
    #    model.add(LSTM({{choice([8, 16, 32, 64, 128])}}, return_sequences=True, stateful=True,
    #                   batch_input_shape=(batch_size, timesteps, data_dim)))
    #    model.add(LSTM({{choice([8, 16, 32, 64, 128])}}, stateful=True,
    #                   batch_input_shape=(batch_size, timesteps, data_dim)))
        
    model.add(Dense(5, activation='relu'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
                  optimizer='sgd')
    
    model.fit(x_train, y_train,
              batch_size=32,
              epochs=10,
              #validation_split=0.08,
              callbacks=[])

    score, acc = model.evaluate(x_test, y_test, verbose=0)

    print('Test accuracy:', acc)
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
def create_model(x_train, y_train, x_test, y_test):
    data_dim = 1
    num_classes = 5
    # Expected input batch shape: (batch_size, timesteps, data_dim)
    # Note that we have to provide the full batch_input_shape since the network is stateful.
    # the sample of index i in batch k is the follow-up for the sample i in batch k-1.
    model = Sequential()
    model.add(LSTM(8, return_sequences=True, input_shape=(1, 1)))
    model.add(LSTM(16))

    model.add(Dropout(0.5))
    model.add(Dense(5, activation='relu'))

    model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
                 optimizer='rmsprop')

   # early_stopping = EarlyStopping(monitor='val_loss', patience=16)

    model.fit(x_train, y_train,
              batch_size=32,
              epochs=10,
              callbacks=[])


    score, acc = model.evaluate(x_test, y_test, verbose=0)

    print('Test accuracy:', acc)
    return {'loss': -acc, 'status': STATUS_OK, 'model': model}

# %%
from keras.utils.np_utils import to_categorical
def data():
    data_dim = 1
    num_classes = 5
    batch_size = 800
    
    # Generate dummy training data
    x_train = np.random.random((batch_size, 1, 1))
    y_train = np.random.randint(4, size=batch_size) + 1

    # Generate dummy validation data
    x_test = np.random.random((batch_size, 1, 1))
    y_test = np.random.randint(4, size=batch_size) + 1
    
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = data()
create_model(x_train, y_train, x_test, y_test)
# Out:
# Epoch 1/10
# 800/800 [==============================] - 1s 808us/step - loss: 3.0611 - acc: 0.2525
# Epoch 2/10
# 800/800 [==============================] - 0s 86us/step - loss: 1.4388 - acc: 0.2487
# Epoch 3/10
# 800/800 [==============================] - 0s 80us/step - loss: 1.4130 - acc: 0.2525
# Epoch 4/10
# 800/800 [==============================] - 0s 84us/step - loss: 1.4096 - acc: 0.2387
# Epoch 5/10
# 800/800 [==============================] - 0s 79us/step - loss: 1.4070 - acc: 0.2450
# Epoch 6/10
# 800/800 [==============================] - 0s 91us/step - loss: 1.4027 - acc: 0.2562
# Epoch 7/10
# 800/800 [==============================] - 0s 81us/step - loss: 1.3913 - acc: 0.2700
# Epoch 8/10
# 800/800 [==============================] - 0s 85us/step - loss: 1.3994 - acc: 0.2337
# Epoch 9/10
# 800/800 [==============================] - 0s 85us/step - loss: 1.3999 - acc: 0.2337
# Epoch 10/10
# ...

# %%
history.history["val_acc"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-a91169a01178> in <module>()
# ----> 1 history.history["val_acc"]
#
# NameError: name 'history' is not defined

# %%
import json
import random

def data():
    ids = list(range(0, 99))
    random.shuffle(ids)

    ids_train = ids[:80]
    ids_test = ids [80:]

    x_train = []
    y_train = []
    x_test = []
    y_test = []

    with open("data_model1.json") as data:
        subjects = json.load(data)

        for subject in subjects:
            subject = np.array(subject)

            x_train.append(np.take(subject[0], ids_train))
            y_train.append(np.take(subject[1], ids_train))
            x_test.append(np.take(subject[0], ids_test))
            y_test.append(np.take(subject[1], ids_test))

    x_train = np.array(x_train).flatten().reshape(-1, 1, 1)
    y_train = np.array(y_train).flatten().reshape(-1, 1, 1)
    x_test = np.array(x_test).flatten().reshape(-1, 1, 1)
    y_test = np.array(y_test).flatten().reshape(-1, 1, 1)

    return x_train, y_train, x_test, y_test

print(data()[0])
# Out:
# [[[12]]
#
#  [[ 8]]
#
#  [[ 9]]
#
#  [[13]]
#
#  [[10]]
#
#  [[ 9]]
#
#  [[10]]
#
#  [[20]]
#
#  [[18]]
#
#  [[10]]
#
#  [[10]]
#
#  [[14]]
#
#  [[11]]
#
#  [[13]]
#
#  [[10]]
#
#  [[ 9]]
#
#  [[11]]
#
#  [[ 8]]
#
#  [[13]]
#
#  [[10]]
#
#  [[ 6]]
#
#  [[12]]
#
#  [[ 8]]
#
#  [[12]]
#
#  [[ 9]]
#
#  [[10]]
#
#  [[10]]
#
#  [[ 8]]
#
#  [[11]]
#
#  [[13]]
#
#  [[ 9]]
#
#  [[11]]
#
#  [[ 9]]
#
#  [[ 8]]
#
#  [[12]]
#
#  [[10]]
#
#  [[14]]
#
#  [[ 8]]
#
#  [[ 9]]
#
#  [[ 8]]
#
#  [[10]]
#
#  [[12]]
#
#  [[13]]
#
#  [[14]]
#
#  [[14]]
#
#  [[11]]
#
#  [[15]]
#
#  [[11]]
#
#  [[13]]
#
#  [[12]]
#
#  [[10]]
#
#  [[ 9]]
#
#  [[ 9]]
#
#  [[11]]
#
#  [[12]]
#
#  [[ 8]]
#
#  [[ 9]]
#
#  [[12]]
#
#  [[ 9]]
#
#  [[13]]
#
#  [[13]]
#
#  [[10]]
#
#  [[10]]
#
#  [[14]]
#
#  [[15]]
#
#  [[11]]
#
#  [[ 5]]
#
#  [[12]]
#
#  [[10]]
#
#  [[14]]
#
#  [[10]]
#
#  [[18]]
#
#  [[12]]
#
#  [[11]]
#
#  [[12]]
#
#  [[13]]
#
#  [[11]]
#
#  [[13]]
#
#  [[11]]
#
#  [[10]]
#
#  [[11]]
#
#  [[10]]
#
#  [[ 9]]
#
# ...
